# %%
from setuptools import setup, find_packages

__version__ = "0.1"
__author__ = "Kalen Cantrell"
__email__ = "kcantrel@ucsd.edu"

required_packages = ["biom-format", "numpy", "pandas",
                     "scikit-bio", "scikit-learn", "scipy", "unifrac"]

classes = """
    Development Status :: 3 - Alpha
    License :: OSI Approved :: BSD License
"""
classifiers = [s.strip() for s in classes.split('\n') if s]

with open('README.md') as f:
    long_description = f.read()

setup(
    name="amplicon_gpt",
    version=__version__,
    description="Deep Learning Methods for amplicon sequencing data",
    long_description=long_description,
    long_description_content_type='text/markdown',
    author=__author__,
    classifiers=classifiers,
    packages=find_packages(),
    install_requires=required_packages,
    python_requires="~=3.9",
    license="BSD-3-Clause"
)
# Out:
# <_io.TextIOWrapper name='README.md' mode='r' encoding='UTF-8'>
# ---------------------------------------------------------------------------
# DistutilsArgError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/setuptools/_distutils/core.py:172, in setup(**attrs)
#     171 try:
# --> 172     ok = dist.parse_command_line()
#     173 except DistutilsArgError as msg:
#
# File /opt/conda/lib/python3.11/site-packages/setuptools/_distutils/dist.py:493, in Distribution.parse_command_line(self)
#     492 if not self.commands:
# --> 493     raise DistutilsArgError("no commands supplied")
#     495 # All is well: return true
#
# DistutilsArgError: no commands supplied
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[7], line 20
#      18 print(f)
# ---> 20 setup(
# ...

# %%
import sys
from setuptools import setup, find_packages

# Reset argv to prevent interference from Jupyter's command-line arguments
original_argv = sys.argv  # Preserve the original argv
sys.argv = [sys.argv[0]]  # Modify argv for the setup call

__version__ = "0.1"
__author__ = "Kalen Cantrell"
__email__ = "kcantrel@ucsd.edu"

required_packages = ["biom-format", "numpy", "pandas",
                     "scikit-bio", "scikit-learn", "scipy", "unifrac"]

classes = """
    Development Status :: 3 - Alpha
    License :: OSI Approved :: BSD License
"""
classifiers = [s.strip() for s in classes.split('\n') if s]

with open('README.md') as f:
    long_description = f.read()

setup(
    name="amplicon_gpt",
    version=__version__,
    description="Deep Learning Methods for amplicon sequencing data",
    long_description=long_description,
    long_description_content_type='text/markdown',
    author=__author__,
    classifiers=classifiers,
    packages=find_packages(),
    install_requires=required_packages,
    python_requires="~=3.9",
    license="BSD-3-Clause"
)

# Restore the original argv
sys.argv = original_argv
# Out:
# ---------------------------------------------------------------------------
# DistutilsArgError                         Traceback (most recent call last)
# File /opt/conda/lib/python3.11/site-packages/setuptools/_distutils/core.py:172, in setup(**attrs)
#     171 try:
# --> 172     ok = dist.parse_command_line()
#     173 except DistutilsArgError as msg:
#
# File /opt/conda/lib/python3.11/site-packages/setuptools/_distutils/dist.py:493, in Distribution.parse_command_line(self)
#     492 if not self.commands:
# --> 493     raise DistutilsArgError("no commands supplied")
#     495 # All is well: return true
#
# DistutilsArgError: no commands supplied
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[6], line 24
#      22     long_description = f.read()
# ---> 24 setup(
#      25     name="amplicon_gpt",
#      26     version=__version__,
# ...
